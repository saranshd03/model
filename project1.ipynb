# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r'G:\New folder (2)\pydoc\refrence project\ref project\Project 9 Credit Card Predictive analysis\default of credit card clients.xls')
df
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1     -1
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
# ...

# %%
pd.set_option('display.max_columns',21)

# %%
sna.histplot(df.PAY_AMT6)
# Out:
# <AxesSubplot:xlabel='PAY_AMT6', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
col=['LIMIT_BAL','BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6']
sns.boxplot(df.LIMIT_BAL)
# Out:
# F:\01Applications\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LIMIT_BAL'>

# %%
for i in col:
    sns.boxplot(col)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4364/3303868331.py in <module>
#       1 for i in col:
# ----> 2     sns.boxplot(col[int(i)])
#
# ValueError: invalid literal for int() with base 10: 'LIMIT_BAL'

# %%
df.nunique()
cat_col=['SEX','EDUCATION','MARRIAGE',"PAY_0",'PAY_2','PAY_3','PAY_4','PAY_5','PAY_6']
# Out:
# LIMIT_BAL                        81
# SEX                               2
# EDUCATION                         7
# MARRIAGE                          4
# AGE                              56
# PAY_0                            11
# PAY_2                            11
# PAY_3                            11
# PAY_4                            11
# PAY_5                            10
# PAY_6                            10
# BILL_AMT1                     22723
# BILL_AMT2                     22346
# BILL_AMT3                     22026
# BILL_AMT4                     21548
# BILL_AMT5                     21010
# BILL_AMT6                     20604
# PAY_AMT1                       7943
# PAY_AMT2                       7899
# PAY_AMT3                       7518
# PAY_AMT4                       6937
# PAY_AMT5                       6897
# PAY_AMT6                       6939
# default payment next month        2
# dtype: int64

# %%
# Visual Inference using Grouped Bar charts
CategoricalColsList=['SEX','EDUCATION','MARRIAGE',"PAY_0",'PAY_2','PAY_3','PAY_4','PAY_5','PAY_6']

import matplotlib.pyplot as plt
fig, PlotCanvas=plt.subplots(nrows=len(CategoricalColsList), ncols=1, figsize=(10,50))

# Creating Grouped bar plots for each categorical predictor against the Target Variable "Loan_Status"
for CategoricalCol , i in zip(CategoricalColsList, range(len(CategoricalColsList))):
    CrossTabResult=pd.crosstab(index=df[CategoricalCol], columns=df['default payment next month'])
    CrossTabResult.plot.bar(color=['red','blue'], ax=PlotCanvas[i])

# %%
df.MARRIAGE.value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64

# %%
#need to treat outliers in limitbal payment and billamt cols

# %%
# Visual Inference using Grouped Bar charts
CategoricalColsList=['SEX','EDUCATION','MARRIAGE',"PAY_0",'PAY_2','PAY_3','PAY_4','PAY_5','PAY_6']

import matplotlib.pyplot as plt
fig, PlotCanvas=plt.subplots(nrows=len(CategoricalColsList), ncols=1, figsize=(10,50))

# Creating Grouped bar plots for each categorical predictor against the Target Variable "Loan_Status"
for CategoricalCol , i in zip(CategoricalColsList, range(len(CategoricalColsList))):
    CrossTabResult=pd.crosstab(index=df[CategoricalCol], columns=df['default payment next month'])
    CrossTabResult.plot.bar(color=['red','blue'], ax=PlotCanvas[i])

# %%
colsToPlot=['SEX','EDUCATION','MARRIAGE',"PAY_0",'PAY_2','PAY_3','PAY_4','PAY_5','PAY_6']

# %%
def PlotBarCharts(inpData, colsToPlot):
    # %matplotlib inline
    
    import matplotlib.pyplot as plt
    
    # Generating multiple subplots
    fig, subPlot=plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(80,20))
    fig.suptitle('Bar charts of: '+ str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
        inpData.groupby(colName).size().plot(kind='bar',ax=subPlot[plotNumber])

#####################################################################
# Calling the function
PlotBarCharts(inpData=df, colsToPlot=['SEX','EDUCATION','MARRIAGE',"PAY_0",'PAY_2','PAY_3','PAY_4','PAY_5','PAY_6'])

# %%
def PlotBarCharts(inpData, colsToPlot):
    # %matplotlib inline
    
    import matplotlib.pyplot as plt
    
    # Generating multiple subplots
    fig, subPlot=plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(80,20))
    fig.suptitle('Bar charts of: '+ str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
        inpData.groupby(colName).size().plot(kind='bar',ax=subPlot[plotNumber])

#####################################################################
# Calling the function
PlotBarCharts(inpData=df, colsToPlot=['SEX','EDUCATION','MARRIAGE',"PAY_0",'PAY_2','PAY_3','PAY_4','PAY_5','PAY_6'])

# %%
col=['LIMIT_BAL','BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6']

# %%
for i in col:
    df.hist([i])

# %%
df.hist(['LIMIT_BAL','BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6'], figsize=(60,60))
# Out:
# array([[<AxesSubplot:title={'center':'LIMIT_BAL'}>,
#         <AxesSubplot:title={'center':'BILL_AMT1'}>,
#         <AxesSubplot:title={'center':'BILL_AMT2'}>],
#        [<AxesSubplot:title={'center':'BILL_AMT3'}>,
#         <AxesSubplot:title={'center':'BILL_AMT4'}>,
#         <AxesSubplot:title={'center':'BILL_AMT5'}>],
#        [<AxesSubplot:title={'center':'BILL_AMT6'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
plt.subplot(1,1,1)
sns.countplot('EDUCATION',hue='default payment next month',data=df)
# Out:
# F:\01Applications\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EDUCATION', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import classification_report,roc_auc_score,accuracy_score,confusion_matrix
#from sklearn.metrics import accuracy_score, confusion_matrix

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
xtr,xte,ytr,yte=train_test_split(x,y,test_size=.20,random_state=55)

# %%
clf=LogisticRegression()

# %%
clf.fit(xtr,ytr)
# Out:
# F:\01Applications\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred=clf.predict(xte)

# %%
pred.shape;ytr.shape
# Out:
# (24000,)

# %%
accuracy_score(yte,pred)
# Out:
# 0.7818333333333334

# %%
print(classification_report(yte,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88      4691
#            1       0.00      0.00      0.00      1309
#
#     accuracy                           0.78      6000
#    macro avg       0.39      0.50      0.44      6000
# weighted avg       0.61      0.78      0.69      6000
# F:\01Applications\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# F:\01Applications\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
pipe=Pipeline([('scaler',StandardScaler()),('logistic',LogisticRegression())])

# %%
pipe.fit(xtr,ytr)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('logistic', LogisticRegression())])

# %%
pr2=pipe.predict(xte)

# %%
print(classification_report(yte,pr2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89      4691
#            1       0.71      0.24      0.36      1309
#
#     accuracy                           0.81      6000
#    macro avg       0.76      0.61      0.63      6000
# weighted avg       0.80      0.81      0.78      6000

# %%
accuracy_score(yte,pr2)
# Out:
# 0.8131666666666667

# %% [markdown]
# # chi2

# %%
from sklearn.feature_selection import SelectKBest,chi2

# %%
selector=SelectKBest(chi2,k=3)
#newX=selector.fit_transform(x,y)

# %%
from sklearn.linear_model import Ridge

# %%
re=Ridge()

# %%
re.fit(xtr,ytr)
# Out:
# Ridge()

# %%
ypred=re.predict(xte)

# %% [markdown]
# # DT

# %%
from sklearn import tree
clf=tree.DecisionTreeClassifier(max_depth=2,criterion='gini')
clf.fit(xtr,ytr)
pre=clf.predict(xte)
print(accuracy_score(yte,pre))
# Out:
# 0.8208333333333333

# %%
clf.fit(xtr,ytr)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
pre=clf.predict(xte)
pre
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
print(classification_report(yte,pre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.89      4691
#            1       0.69      0.32      0.44      1309
#
#     accuracy                           0.82      6000
#    macro avg       0.76      0.64      0.67      6000
# weighted avg       0.80      0.82      0.79      6000
